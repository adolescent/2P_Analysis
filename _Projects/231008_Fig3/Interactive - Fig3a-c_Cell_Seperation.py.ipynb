# %%
    def update(frame):
        ax.view_init(elev=25, azim=frame)  # Update the view angle for each frame
        return ax,

# %%
from matplotlib.animation import FuncAnimation

# %%
    ot.mkdir(cc_path)
    plt.clf()
    plt.cla()
    fig = plt.figure(figsize = (8,8))
    ax = plt.axes(projection='3d')
    ax.grid(False)
    sc = ax.scatter3D(u[:,0], u[:,1], u[:,2],s = 5,c = OD_bar,cmap = 'bwr')
    cbar = fig.colorbar(sc, shrink=0.5)
    cbar.set_label('OD t value')
    ax.set_xlabel('UMAP 1')
    ax.set_ylabel('UMAP 2')
    ax.set_zlabel('UMAP 3')
    azim_list = [30,60,120,150,210,240,300,330]
    for i,c_azim in enumerate(azim_list):
        ax.view_init(elev=25, azim=c_azim)
        plt.savefig(f'{cc_path}\\OD_Plot_{c_azim}.png', dpi=180)
    # and a gif.
    animation = FuncAnimation(fig, update, frames=range(0, 360, 5), interval=150)
    animation.save(f'{cc_path}\\OD_Plot_3D.gif', writer='pillow')
# Out:
# Folder D:\_Path_For_Figs\Fig3_Cell_Seperation\L76_18M_220902 already exists!

# %%
    plt.clf()
    plt.cla()
    fig = plt.figure(figsize = (8,8))
    ax = plt.axes(projection='3d')
    ax.grid(False)
    sc = ax.scatter3D(u[:,0], u[:,1], u[:,2],s = 5,c = dist_bar,cmap = 'bwr')
    cbar = fig.colorbar(sc, shrink=0.5)
    cbar.set_label('Distance')
    ax.set_xlabel('UMAP 1')
    ax.set_ylabel('UMAP 2')
    ax.set_zlabel('UMAP 3')
    azim_list = [30,60,120,150,210,240,300,330]
    for i,c_azim in enumerate(azim_list):
        ax.view_init(elev=25, azim=c_azim)
        plt.savefig(f'{cc_path}\\Dist_Plot_{c_azim}.png', dpi=180)
    # and a gif.
    animation = FuncAnimation(fig, update, frames=range(0, 360, 5), interval=150)
    animation.save(f'{cc_path}\\Dist_Plot_3D.gif', writer='pillow')

# %%
RGB_matrix = np.array([[255, 0, 0], [0, 255, 0], [0, 0, 255]])  # Example RGB matrix

fig = plt.figure(figsize=(12, 10))
ax = fig.add_subplot(111, projection='3d')
ax.grid(False)

# Create a custom colormap using the RGB values
custom_cmap = mcolors.ListedColormap(RGB_matrix / 255.0)

# Plot the scatter points with the custom colormap
sc = ax.scatter3D(u[:, 0], u[:, 1], u[:, 2], s=5, c=OD_bar, cmap=custom_cmap)

cbar = fig.colorbar(sc)
cbar.set_label('Colorbar Label')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[161], line 8
#       5 ax.grid(False)
#       7 # Create a custom colormap using the RGB values
# ----> 8 custom_cmap = mcolors.ListedColormap(RGB_matrix / 255.0)
#      10 # Plot the scatter points with the custom colormap
#      11 sc = ax.scatter3D(u[:, 0], u[:, 1], u[:, 2], s=5, c=OD_bar, cmap=custom_cmap)
#
# NameError: name 'mcolors' is not defined

# %%
import matplotlib.colors as mcolors

# %%
RGB_matrix = np.array([[255, 0, 0], [0, 255, 0], [0, 0, 255]])  # Example RGB matrix

fig = plt.figure(figsize=(12, 10))
ax = fig.add_subplot(111, projection='3d')
ax.grid(False)

# Create a custom colormap using the RGB values
custom_cmap = mcolors.ListedColormap(RGB_matrix / 255.0)

# Plot the scatter points with the custom colormap
sc = ax.scatter3D(u[:, 0], u[:, 1], u[:, 2], s=5, c=OD_bar, cmap=custom_cmap)

cbar = fig.colorbar(sc)
cbar.set_label('Colorbar Label')

plt.show()

# %%
orien_bar = cc['Orien_Hue']
custom_cmap = mcolors.ListedColormap(OD_bar.T)

# %%
    plt.clf()
    plt.cla()
    fig = plt.figure(figsize = (8,8))
    ax = plt.axes(projection='3d')
    ax.grid(False)
    sc = ax.scatter3D(u[:,0], u[:,1], u[:,2],s = 5,c = orien_bar,cmap = custom_cmap)
    cbar = fig.colorbar(sc, shrink=0.5)
    cbar.set_label('Distance')
    ax.set_xlabel('UMAP 1')
    ax.set_ylabel('UMAP 2')
    ax.set_zlabel('UMAP 3')
# Out:
# <ipython-input-165-bab99cc8db3e>:6: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   sc = ax.scatter3D(u[:,0], u[:,1], u[:,2],s = 5,c = orien_bar,cmap = custom_cmap)
# Text(0.5, 0, 'UMAP 3')

# %%
orien_bar = cc['Orien_Hue']
custom_cmap = mcolors.ListedColormap(orien_bar)

# %%
    plt.clf()
    plt.cla()
    fig = plt.figure(figsize = (8,8))
    ax = plt.axes(projection='3d')
    ax.grid(False)
    sc = ax.scatter3D(u[:,0], u[:,1], u[:,2],s = 5,c = orien_bar,cmap = custom_cmap)
    cbar = fig.colorbar(sc, shrink=0.5)
    cbar.set_label('Distance')
    ax.set_xlabel('UMAP 1')
    ax.set_ylabel('UMAP 2')
    ax.set_zlabel('UMAP 3')
# Out:
# <ipython-input-167-bab99cc8db3e>:6: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   sc = ax.scatter3D(u[:,0], u[:,1], u[:,2],s = 5,c = orien_bar,cmap = custom_cmap)
# Text(0.5, 0, 'UMAP 3')

# %%
orien_bar = cc['Orien_Hue']
custom_cmap = mcolors.ListedColormap(orien_bar.T)

# %%
    plt.clf()
    plt.cla()
    fig = plt.figure(figsize = (8,8))
    ax = plt.axes(projection='3d')
    ax.grid(False)
    sc = ax.scatter3D(u[:,0], u[:,1], u[:,2],s = 5,c = orien_bar,cmap = custom_cmap)
    cbar = fig.colorbar(sc, shrink=0.5)
    cbar.set_label('Distance')
    ax.set_xlabel('UMAP 1')
    ax.set_ylabel('UMAP 2')
    ax.set_zlabel('UMAP 3')
# Out:
# <ipython-input-169-bab99cc8db3e>:6: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   sc = ax.scatter3D(u[:,0], u[:,1], u[:,2],s = 5,c = orien_bar,cmap = custom_cmap)
# Text(0.5, 0, 'UMAP 3')

# %%
custom_cmap
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File d:\Anaconda\envs\caiman\lib\site-packages\IPython\core\formatters.py:344, in BaseFormatter.__call__(self, obj)
#     <a href='file:///d%3A/Anaconda/envs/caiman/lib/site-packages/IPython/core/formatters.py?line=341'>342</a>     method = get_real_method(obj, self.print_method)
#     <a href='file:///d%3A/Anaconda/envs/caiman/lib/site-packages/IPython/core/formatters.py?line=342'>343</a>     if method is not None:
# --> <a href='file:///d%3A/Anaconda/envs/caiman/lib/site-packages/IPython/core/formatters.py?line=343'>344</a>         return method()
#     <a href='file:///d%3A/Anaconda/envs/caiman/lib/site-packages/IPython/core/formatters.py?line=344'>345</a>     return None
#     <a href='file:///d%3A/Anaconda/envs/caiman/lib/site-packages/IPython/core/formatters.py?line=345'>346</a> else:
#
# ...

# %%
orien_bar = cc['Orien_Hue']
custom_cmap = mcolors.ListedColormap(orien_bar)

# %%
custom_cmap

# %%
    plt.clf()
    plt.cla()
    fig = plt.figure(figsize = (8,8))
    ax = plt.axes(projection='3d')
    ax.grid(False)
    sc = ax.scatter3D(u[:,0], u[:,1], u[:,2],s = 5,c = orien_bar,cmap = custom_cmap)
    cbar = fig.colorbar(sc, shrink=0.5)
    cbar.set_label('Distance')
    ax.set_xlabel('UMAP 1')
    ax.set_ylabel('UMAP 2')
    ax.set_zlabel('UMAP 3')
# Out:
# <ipython-input-173-bab99cc8db3e>:6: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   sc = ax.scatter3D(u[:,0], u[:,1], u[:,2],s = 5,c = orien_bar,cmap = custom_cmap)
# Text(0.5, 0, 'UMAP 3')

# %%
set(custom_cmap)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[174], line 1
# ----> 1 set(custom_cmap)
#
# TypeError: 'ListedColormap' object is not iterable

# %%
OD_bar = np.array([[0.2, 0.4, 0.6, 0.8], [0.3, 0.5, 0.7, 0.9], [0.1, 0.3, 0.5, 0.7]])  # Example OD_bar
id_list = ['ID1', 'ID2', 'ID3', 'ID4', 'ID5', 'ID6', 'ID7', 'ID8']  # Example ID list

fig = plt.figure(figsize=(12, 10))
ax = fig.add_subplot(111, projection='3d')
ax.grid(False)

# Create a custom colormap using the OD_bar matrix
custom_cmap = mcolors.ListedColormap(OD_bar.T)

# Generate a dummy x, y, z coordinates for visualization
num_samples = OD_bar.shape[1]
x = np.random.rand(num_samples)
y = np.random.rand(num_samples)
z = np.random.rand(num_samples)

# Plot the scatter points with the custom colormap
sc = ax.scatter3D(x, y, z, s=5, c=range(num_samples), cmap=custom_cmap)

cbar = fig.colorbar(sc)
cbar.set_label('Colorbar Label')

# Set the colorbar ticks and labels
num_ticks = 8
tick_positions = np.linspace(0, num_samples - 1, num_ticks, dtype=int)
tick_labels = [id_list[i] for i in tick_positions]

cbar.set_ticks(tick_positions)
cbar.set_ticklabels(tick_labels)

plt.show()

# %%
OD_bar = orien_bar  # Example OD_bar
id_list = ['ID1', 'ID2', 'ID3', 'ID4', 'ID5', 'ID6', 'ID7', 'ID8']  # Example ID list

fig = plt.figure(figsize=(12, 10))
ax = fig.add_subplot(111, projection='3d')
ax.grid(False)

# Create a custom colormap using the OD_bar matrix
custom_cmap = mcolors.ListedColormap(OD_bar.T)

# Generate a dummy x, y, z coordinates for visualization
num_samples = OD_bar.shape[1]
x = np.random.rand(num_samples)
y = np.random.rand(num_samples)
z = np.random.rand(num_samples)

# Plot the scatter points with the custom colormap
sc = ax.scatter3D(x, y, z, s=5, c=range(num_samples), cmap=custom_cmap)

cbar = fig.colorbar(sc)
cbar.set_label('Colorbar Label')

# Set the colorbar ticks and labels
num_ticks = 8
tick_positions = np.linspace(0, num_samples - 1, num_ticks, dtype=int)
tick_labels = [id_list[i] for i in tick_positions]

cbar.set_ticks(tick_positions)
cbar.set_ticklabels(tick_labels)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[176], line 18
#      15 z = np.random.rand(num_samples)
#      17 # Plot the scatter points with the custom colormap
# ---> 18 sc = ax.scatter3D(x, y, z, s=5, c=range(num_samples), cmap=custom_cmap)
#      20 cbar = fig.colorbar(sc)
#      21 cbar.set_label('Colorbar Label')
#
# File d:\Anaconda\envs\caiman\lib\site-packages\matplotlib\__init__.py:1465, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    <a href='file:///d%3A/Anaconda/envs/caiman/lib/site-packages/matplotlib/__init__.py?line=1461'>1462</a> @functools.wraps(func)
#    <a href='file:///d%3A/Anaconda/envs/caiman/lib/site-packages/matplotlib/__init__.py?line=1462'>1463</a> def inner(ax, *args, data=None, **kwargs):
#    <a href='file:///d%3A/Anaconda/envs/caiman/lib/site-packages/matplotlib/__init__.py?line=1463'>1464</a>     if data is None:
# ...
